# %%
list1 = []
with open("/content/drive/MyDrive/Nodule_Mass/val.txt",'r') as reader:
    for line in reader.readlines():
        list1.append(line)

# %%
list1[:2]
# Out:
# ['/kaggle/working/vinbigdata/images/val/04d3efc7a608c4d58edb8c1b7f90a708.png\n',
#  '/kaggle/working/vinbigdata/images/val/c12df5422711be0ed7b17a657c68fc8d.png\n']

# %%
x = "'/kaggle/working/vinbigdata/images/val/04d3efc7a608c4d58edb8c1b7f90a708.png\n'"
"/content/drive/MyDrive/Nodule_Mass" + x[16:]
# Out:
# "/content/drive/MyDrive/Nodule_Mass/vinbigdata/images/val/04d3efc7a608c4d58edb8c1b7f90a708.png\n'"

# %%
"/content/drive/MyDrive/Nodule_Mass/vinbigdata/images/train/010018c93ed33ae56ed048ee54867e46.png"

# %%
final_list = []
for i in list1:
    x = "/content/drive/MyDrive/Nodule_Mass" + i[16:]
    final_list.append(x)

# %%
with open("/content/drive/MyDrive/Nodule_Mass/val.txt",'r+') as f:
    for i in final_list:
        f.write(i)
        f.write("")
    f.truncate()
